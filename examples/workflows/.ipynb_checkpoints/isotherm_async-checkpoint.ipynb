# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from aiida import load_dbenv
load_dbenv()

# %%
from aiida.orm.utils import DataFactory
from aiida.work.workfunction import workfunction as wf
from aiida.orm import DataFactory
from aiida.orm.data.base import Str
from aiida.orm.data.base import List
import ase
from aiida.orm.code import Code

# %%
# %matplotlib notebook

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib.pyplot import plot, draw, show, ion

# %%
pressures = [0.1, 1, 5, 10, 20, 30, 40, 60]

# %%
from aiida_raspa.calculations import RaspaCalculation
from aiida.orm.data.base import Float
from aiida.work.run import run, submit

# %%
def generate_input_params(codename, pressure=10):
    # The inputs
    inputs = RaspaCalculation.process().get_inputs_template()

    inputs.code = Code.get_from_string(codename.value)
    inputs._options.resources = {"num_machines": 1, "num_mpiprocs_per_machine":1}
    inputs._options.max_wallclock_seconds = 30 * 60

    # Calculation parameters
    parameters_dict = {
    "GeneralSettings":
    {
    "SimulationType"                   : "MonteCarlo",
    "NumberOfCycles"                   : 25000,
    "NumberOfInitializationCycles"     : 3000,
    "RestartFile"                      : "no",
    "PrintEvery"                       : 1000,
    "Forcefield"                       : "GarciaPerez2006",
    "ModifyOxgensConnectedToAluminium" : "yes",
    "Framework"                        : 0,
    "FrameworkName"                    : "LTA4A",
    "RemoveAtomNumberCodeFromLabel"    : "yes",
    "UnitCells"                        : [1, 1, 1],
    "ExternalTemperature"              : 298.0,
    "ExternalPressure"                 : pressure,
    },
    "Component":
    [{
    "MoleculeName"                     : "methane",
    "MoleculeDefinition"               : "TraPPE",
    "BlockPockets"                     : "yes",
    "BlockPocketsFilename"             : "LTA",
    "TranslationProbability"           : 1.0,
    "ReinsertionProbability"           : 1.0,
    "SwapProbability"                  : 1.0,
    "ExtraFrameworkMolecule"           : "no",
    "CreateNumberOfMolecules"          : 0,
    }],  
    }
    ParameterData = DataFactory("parameter")
    inputs.parameters = ParameterData(dict=parameters_dict)


    return inputs

# %%
@wf
def isoterm(codename):
    Process = RaspaCalculation.process()
    futures = {}
    for p in pressures:
        inputs = generate_input_params(codename, p*100000)
        futures[p] = submit(Process, **inputs)
    results = []
    for s, future in futures.iteritems():
        res = future.result()['output_parameters']
        res_dict=res.dict
        restults.append(res_dict.number_of_adsorbates)
    return results

# %%
class Plotter(object):
     def __init__(self, scales):
         self._scales = scales
         self._fig, self._ax = plt.subplots()
         self._ax.set_title("Absorption isotherm of methane in LTA4A")
         self._ax.set_xlabel(u"Pressure [bar]")
         self._ax.set_ylabel(u"Number of Molecules/Unit Cell")
         self._ax.set_xlim([scales[0], scales[-1]])
         self._line, = self._ax.plot([], [], marker='o')

     def plot(self, energies):
         self._line.set_xdata(self._scales[0:len(energies)])
         self._line.set_ydata(energies)
         self._ax.relim()
         self._ax.autoscale_view()
         self._fig.canvas.draw()
            
plt_my=Plotter(pressures)
#plt_my.plot([1,2])
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
result = isoterm(Str('raspa@hypatia')) # doctest: +SKIP
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8dd5acd98b51> in <module>()
# ----> 1 result = isoterm(Str('raspa@hypatia')) # doctest: +SKIP
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/aiida/work/workfunction.pyc in wrapped_function(*args, **kwargs)
#      54         pid = future.pid
#      55
# ---> 56         results = future.result()
#      57         # Check if there is just one value returned
#      58         if len(results) == 1 and FuncProc.SINGLE_RETURN_LINKNAME in results:
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/plum/engine/serial.pyc in __init__(self, func, process, *args, **kwargs)
#      31             # Run the damn thing
#      32             try:
# ---> 33                 func(process, *args, **kwargs)
#      34                 self._set_result(process.outputs)
#      35             except KeyboardInterrupt:
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/plum/process.pyc in run_until_complete(self)
#     320
#     321     def run_until_complete(self):
# --> 322         self.__director.run_till_end()
#     323
#     324     def stop(self, execute=False):
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/plum/process.pyc in run_till_end(self)
#     814     def run_till_end(self):
#     815         while self._proc.state is not ProcessState.DESTROYED:
# --> 816             if self._proc.tick() is False:
#     817                 time.sleep(5)
#     818
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/plum/process.pyc in tick(self)
#     281
#     282     def tick(self):
# --> 283         return self.__director.tick()
#     284
#     285     def run_until(self, process_state=ProcessState.DESTROYED, break_on_wait_not_ready=False):
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/plum/process.pyc in tick(self)
#     777                     # STARTED -> RUNNING -> WAITING or FINISHED
#     778                     self._proc.perform_run()
# --> 779                     self._finish_running(self._proc.do_run())
#     780                     return True
#     781             elif self._proc.state is ProcessState.WAITING:
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/aiida/work/process.pyc in do_run(self)
#     284         # Exclude all private inputs
#     285         ins = {k: v for k, v in self.inputs.iteritems() if not k.startswith('_')}
# --> 286         return self._run(**ins)
#     287
#     288     @protected
#
# /home/epfl/work/venv-lsmo/lib/python2.7/site-packages/aiida/work/process.pyc in _run(self, **kwargs)
#     490         for arg in self._func_args:
#     491             args.append(kwargs.pop(arg))
# --> 492         outs = self._func(*args, **kwargs)
#     493         if outs is not None:
#     494             if isinstance(outs, Data):
#
# <ipython-input-8-8589c1c0c4f7> in isoterm(codename)
#       8     results = []
#       9     for s, future in futures.iteritems():
# ---> 10         res = future.result()['output_parameters']
#      11         res_dict=res.dict
#      12         restults.append(res_dict.number_of_adsorbates)
#
# AttributeError: 'RunningInfo' object has no attribute 'result'

# %%
plt_my.plot(result)
